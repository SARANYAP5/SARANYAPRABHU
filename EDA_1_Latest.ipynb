# %% [markdown]
# # Exploratory Data Analysis

# %%
#load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
data = pd.read_csv("data_clean.csv")
data.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
#Data Structure 
print(type(data))
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)

# %%
data.shape[0]
# Out:
# 158

# %%
#data types
data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
data.describe()
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind         Day    Year  \
# count  158.000000  120.000000  151.000000  158.000000  158.000000   158.0
# mean    79.500000   41.583333  185.403974    9.957595   16.006329  2010.0
# std     45.754781   32.620709   88.723103    3.511261    8.997166     0.0
# min      1.000000    1.000000    7.000000    1.700000    1.000000  2010.0
# 25%     40.250000   18.000000  119.000000    7.400000    8.000000  2010.0
# 50%     79.500000   30.500000  197.000000    9.700000   16.000000  2010.0
# 75%    118.750000   61.500000  257.000000   11.875000   24.000000  2010.0
# max    158.000000  168.000000  334.000000   20.700000   31.000000  2010.0
#
#              Temp
# count  158.000000
# mean    77.727848
# std      9.377877
# min     56.000000
# 25%     72.000000
# 50%     78.500000
# 75%     84.000000
# max     97.000000

# %%
data.describe(include="all")
# Out:
#         Unnamed: 0       Ozone     Solar.R        Wind Temp C Month  \
# count   158.000000  120.000000  151.000000  158.000000    158   158
# unique         NaN         NaN         NaN         NaN     41     6
# top            NaN         NaN         NaN         NaN     81     9
# freq           NaN         NaN         NaN         NaN     11    34
# mean     79.500000   41.583333  185.403974    9.957595    NaN   NaN
# std      45.754781   32.620709   88.723103    3.511261    NaN   NaN
# min       1.000000    1.000000    7.000000    1.700000    NaN   NaN
# 25%      40.250000   18.000000  119.000000    7.400000    NaN   NaN
# 50%      79.500000   30.500000  197.000000    9.700000    NaN   NaN
# 75%     118.750000   61.500000  257.000000   11.875000    NaN   NaN
# max     158.000000  168.000000  334.000000   20.700000    NaN   NaN
#
#                Day    Year        Temp Weather
# count   158.000000   158.0  158.000000     155
# unique         NaN     NaN         NaN       3
# top            NaN     NaN         NaN       S
# freq           NaN     NaN         NaN      59
# mean     16.006329  2010.0   77.727848     NaN
# std       8.997166     0.0    9.377877     NaN
# min       1.000000  2010.0   56.000000     NaN
# 25%       8.000000  2010.0   72.000000     NaN
# 50%      16.000000  2010.0   78.500000     NaN
# 75%      24.000000  2010.0   84.000000     NaN
# max      31.000000  2010.0   97.000000     NaN

# %% [markdown]
# # Data type conversion

# %%
data.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
data['Month']=pd.to_numeric(data['Month'],errors='coerce') #[1,1.5,NAN] january NA
data['Temp C']=pd.to_numeric(data['Temp C'],errors='coerce')# coerce will introduce NA values for non numeric data in the columns
data['Weather']=data['Weather'].astype('category')           #data['Wind']=data['Wind'].astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      157 non-null    float64
#  5   Month       157 non-null    float64
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    category
# dtypes: category(1), float64(5), int64(4)
# memory usage: 11.5 KB

# %% [markdown]
# ####More on data type conversions
# [link text](https://stackoverflow.com/questions/15891038/change-column-type-in-pandas)

# %% [markdown]
# ### Drop Columns

# %%
data.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 1           2   36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 2           3   12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 3           4   18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 4           5    NaN      NaN  14.3    56.0    5.0    5  2010    56       S

# %%
data1 = data.drop('Unnamed: 0',axis=1)

# %%
data1
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 157   18.0    131.0   8.0    76.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %% [markdown]
# ### Remove duplicated rows

# %%
data1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156     True
# 157    False
# Length: 158, dtype: bool

# %%
data1.iloc[140:157]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 140   13.0     27.0  10.3    76.0    9.0   18  2010    76       S
# 141   24.0    238.0  10.3    68.0    9.0   19  2010    68       C
# 142   16.0    201.0   8.0    82.0    9.0   20  2010    82      PS
# 143   13.0    238.0  12.6    64.0    9.0   21  2010    64      PS
# 144   23.0     14.0   9.2    71.0    9.0   22  2010    71       S
# 145   36.0    139.0  10.3    81.0    9.0   23  2010    81       S
# 146    7.0     49.0  10.3    69.0    9.0   24  2010    69       C
# 147   14.0     20.0  16.6    63.0    9.0   25  2010    63      PS
# 148   30.0    193.0   6.9    70.0    9.0   26  2010    70       C
# 149    NaN    145.0  13.2    77.0    9.0   27  2010    77      PS
# 150   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 151   18.0    131.0   8.0    76.0    9.0   29  2010    76      PS
# 152   20.0    223.0  11.5    68.0    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S

# %%
#Print the duplicated rows
data1[data1.duplicated(keep=False)]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S

# %%
data1[data1.duplicated(keep="first")]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S

# %%
data1[data1.duplicated(keep="last")]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3    75.0    9.0   28  2010    75       S

# %%
data_cleaned1=data1.drop_duplicates(keep="first")

# %%
data_cleaned1[data_cleaned1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Ozone, Solar.R, Wind, Temp C, Month, Day, Year, Temp, Weather]
# Index: []

# %%
data1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156     True
# 157    False
# Length: 158, dtype: bool

# %% [markdown]
# # Drop columns

# %%
data_cleaned1
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5    68.0    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 157   18.0    131.0   8.0    76.0    9.0   29  2010    76       C
#
# [157 rows x 9 columns]

# %%
# data_cleaned1.drop('Temp C',axis=1, inplace =True)

# %%
data_cleaned2=data_cleaned1.drop('Temp C',axis=1)

# %%
data_cleaned2
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    9.0   27  2010    77       S
# 157   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %% [markdown]
# # Rename the columns

# %%
#rename the Solar column
data_cleaned3 = data_cleaned2.rename({'Solar.R': 'Solar'}, axis=1)

# %%
data_cleaned3.head()
# Out:
#    Ozone  Solar  Wind  Month  Day  Year  Temperature Weather
# 0   41.0  190.0   7.4    5.0    1  2010           67       S
# 1   36.0  118.0   8.0    5.0    2  2010           72       C
# 2   12.0  149.0  12.6    5.0    3  2010           74      PS
# 3   18.0  313.0  11.5    5.0    4  2010           62       S
# 4    NaN    NaN  14.3    5.0    5  2010           56       S

# %%
data_cleaned3.columns
# Out:
# Index(['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Year', 'Temp', 'Weather'], dtype='object')

# %%
data_cleaned3.columns = ['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Year', 'Temperature', 'Weather']

# %%
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temperature Weather
# 0     41.0  190.0   7.4    5.0    1  2010           67       S
# 1     36.0  118.0   8.0    5.0    2  2010           72       C
# 2     12.0  149.0  12.6    5.0    3  2010           74      PS
# 3     18.0  313.0  11.5    5.0    4  2010           62       S
# 4      NaN    NaN  14.3    5.0    5  2010           56       S
# ..     ...    ...   ...    ...  ...   ...          ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010           68       S
# 153   41.0  190.0   7.4    5.0    1  2010           67       C
# 154   30.0  193.0   6.9    9.0   26  2010           70      PS
# 155    NaN  145.0  13.2    9.0   27  2010           77       S
# 157   18.0  131.0   8.0    9.0   29  2010           76       C
#
# [157 rows x 8 columns]

# %%
data_cleaned3.columns = ['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Year', 'Temp', 'Weather']

# %%
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4      NaN    NaN  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155    NaN  145.0  13.2    9.0   27  2010    77       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %% [markdown]
# # Missing Values and Imputation

# %%
data_cleaned3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    119 non-null    float64
#  1   Solar    150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    156 non-null    float64
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  154 non-null    category
# dtypes: category(1), float64(4), int64(3)
# memory usage: 10.1 KB

# %%
import seaborn as sns
cols = data_cleaned3.columns 
colours = ['black', 'yellow'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(data_cleaned3[cols].isnull(),
            cmap=sns.color_palette(colours), cbar = True)
# Out:
# <Axes: >

# %%
data_cleaned3[data_cleaned3.isnull().any(axis=1)]
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 4      NaN    NaN  14.3    5.0    5  2010    56       S
# 5     28.0    NaN  14.9    5.0    6  2010    66       C
# 9      NaN  194.0   8.6    5.0   10  2010    69       S
# 10     7.0    NaN   6.9    5.0   11  2010    74       C
# 23    32.0   92.0  12.0    NaN   24  2010    61       C
# 24     NaN   66.0  16.6    5.0   25  2010    57      PS
# 25     NaN  266.0  14.9    5.0   26  2010    58       C
# 26     NaN    NaN   8.0    5.0   27  2010    57      PS
# 31     NaN  286.0   8.6    6.0    1  2010    78       S
# 32     NaN  287.0   9.7    6.0    2  2010    74       C
# 33     NaN  242.0  16.1    6.0    3  2010    67      PS
# 34     NaN  186.0   9.2    6.0    4  2010    84       C
# 35     NaN  220.0   8.6    6.0    5  2010    85      PS
# 36     NaN  264.0  14.3    6.0    6  2010    79       C
# 38     NaN  273.0   6.9    6.0    8  2010    87       S
# 41     NaN  259.0  10.9    6.0   11  2010    93       C
# 42     NaN  250.0   9.2    6.0   12  2010    92      PS
# 44     NaN  332.0  13.8    6.0   14  2010    80       S
# 45     NaN  322.0  11.5    6.0   15  2010    79       C
# 51     NaN  150.0   6.3    6.0   21  2010    77       S
# 52     NaN   59.0   1.7    6.0   22  2010    76       C
# 53     NaN   91.0   4.6    6.0   23  2010    76      PS
# 54     NaN  250.0   6.3    6.0   24  2010    76       S
# 55     NaN  135.0   8.0    6.0   25  2010    75       C
# 56     NaN  127.0   8.0    6.0   26  2010    78      PS
# 57     NaN   47.0  10.3    6.0   27  2010    73       C
# 58     NaN   98.0  11.5    6.0   28  2010    80      PS
# 59     NaN   31.0  14.9    6.0   29  2010    77       S
# 60     NaN  138.0   8.0    6.0   30  2010    83       S
# 64     NaN  101.0  10.9    7.0    4  2010    84       S
# 71     NaN  139.0   8.6    7.0   11  2010    82       S
# 74     NaN  291.0  14.9    7.0   14  2010    91       C
# 82     NaN  258.0   9.7    7.0   22  2010    81       S
# 83     NaN  295.0  11.5    7.0   23  2010    82       C
# 87    52.0   82.0  12.0    7.0   27  2010    86     NaN
# 93     9.0   24.0  13.8    8.0    2  2010    81     NaN
# 95    78.0    NaN   6.9    8.0    4  2010    86     NaN
# 96    35.0    NaN   7.4    8.0    5  2010    85       S
# 97    66.0    NaN   4.6    8.0    6  2010    87       C
# 101    NaN  222.0   8.6    8.0   10  2010    92      PS
# 102    NaN  137.0  11.5    8.0   11  2010    86       S
# 106    NaN   64.0  11.5    8.0   15  2010    79       C
# 114    NaN  255.0  12.6    8.0   23  2010    75      PS
# 118    NaN  153.0   5.7    8.0   27  2010    88       S
# 149    NaN  145.0  13.2    9.0   27  2010    77      PS
# 155    NaN  145.0  13.2    9.0   27  2010    77       S

# %%
# data_of_nulls = data_cleaned3[cols].isnull()
# column_names = list(data_cleaned3.columns)

# data_of_nulls

# %%
# for i in column_names:
#   if True in list(data_of_nulls[i]):
#     print(i)

# %%
data_cleaned3.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
data_cleaned3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    119 non-null    float64
#  1   Solar    150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    156 non-null    float64
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  154 non-null    category
# dtypes: category(1), float64(4), int64(3)
# memory usage: 10.1 KB

# %%
#Imputation of missing value with median
median = data_cleaned3['Solar'].median()
print(median)
# Out:
# 199.0

# %%
data_cleaned3['Solar'] = data_cleaned3['Solar'].fillna(median)

# %%
data_cleaned3
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4    5.0    1  2010    67       S
# 1     36.0  118.0   8.0    5.0    2  2010    72       C
# 2     12.0  149.0  12.6    5.0    3  2010    74      PS
# 3     18.0  313.0  11.5    5.0    4  2010    62       S
# 4      NaN  199.0  14.3    5.0    5  2010    56       S
# ..     ...    ...   ...    ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5    9.0   30  2010    68       S
# 153   41.0  190.0   7.4    5.0    1  2010    67       C
# 154   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155    NaN  145.0  13.2    9.0   27  2010    77       S
# 157   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
data_cleaned3.isnull().sum()
# Out:
# Ozone      38
# Solar       0
# Wind        0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
mean = data_cleaned3["Ozone"].mean()

# %%
data_cleaned3['Ozone'] = data_cleaned3["Ozone"].fillna(mean)

# %%
data_cleaned3["Ozone"].isnull().sum()
# Out:
# 0

# %%
data_cleaned3["Weather"].value_counts()
# Out:
# S     58
# C     49
# PS    47
# Name: Weather, dtype: int64

# %%
#Missing value imputation for categorical vlaue
#Get the object columns
obj_columns=data_cleaned3[['Weather']]

# %%
obj_columns.isnull().sum()
# Out:
# Weather    3
# dtype: int64

# %%
mode = obj_columns.mode().loc[0]

# %%
mode
# Out:
# Weather    S
# Name: 0, dtype: category
# Categories (3, object): ['C', 'PS', 'S']

# %%
#Missing value imputation for categorical value
# df.mode
# df.median//////
obj_columns=obj_columns.fillna(mode)
obj_columns
# Out:
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ..      ...
# 152       S
# 153       C
# 154      PS
# 155       S
# 157       C
#
# [157 rows x 1 columns]

# %%
obj_columns.isnull().sum()
# Out:
# Weather    0
# dtype: int64

# %%
data_cleaned3["Weather"] = obj_columns["Weather"]

# %%
data_cleaned3
# Out:
#          Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0    41.000000  190.0   7.4    5.0    1  2010    67       S
# 1    36.000000  118.0   8.0    5.0    2  2010    72       C
# 2    12.000000  149.0  12.6    5.0    3  2010    74      PS
# 3    18.000000  313.0  11.5    5.0    4  2010    62       S
# 4    41.815126  199.0  14.3    5.0    5  2010    56       S
# ..         ...    ...   ...    ...  ...   ...   ...     ...
# 152  20.000000  223.0  11.5    9.0   30  2010    68       S
# 153  41.000000  190.0   7.4    5.0    1  2010    67       C
# 154  30.000000  193.0   6.9    9.0   26  2010    70      PS
# 155  41.815126  145.0  13.2    9.0   27  2010    77       S
# 157  18.000000  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
data_cleaned3["Weather"].isnull().sum()
# Out:
# 0

# %%
obj_columns.shape
# Out:
# (157, 1)

# %%
#data_cleaned4=data_cleaned3.drop(['Weather'],axis=1,inplace=True)

# %%
#Join the data set with imputed object dataset
data_cleaned4=pd.concat([data_cleaned3,obj_columns],axis=1)

# %%
data_cleaned4.isnull().sum()
# Out:
# Ozone      0
# Solar      0
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    0
# Weather    0
# dtype: int64

# %%
data_cleaned4
# Out:
#          Ozone  Solar  Wind  Month  Day  Year  Temp Weather Weather
# 0    41.000000  190.0   7.4    5.0    1  2010    67       S       S
# 1    36.000000  118.0   8.0    5.0    2  2010    72       C       C
# 2    12.000000  149.0  12.6    5.0    3  2010    74      PS      PS
# 3    18.000000  313.0  11.5    5.0    4  2010    62       S       S
# 4    41.815126  199.0  14.3    5.0    5  2010    56       S       S
# ..         ...    ...   ...    ...  ...   ...   ...     ...     ...
# 152  20.000000  223.0  11.5    9.0   30  2010    68       S       S
# 153  41.000000  190.0   7.4    5.0    1  2010    67       C       C
# 154  30.000000  193.0   6.9    9.0   26  2010    70      PS      PS
# 155  41.815126  145.0  13.2    9.0   27  2010    77       S       S
# 157  18.000000  131.0   8.0    9.0   29  2010    76       C       C
#
# [157 rows x 9 columns]

# %%
#Bar plot
data['Weather'].value_counts()
#.plot.bar()
# Out:
# S     59
# C     49
# PS    47
# Name: Weather, dtype: int64

# %% [markdown]
# # Outlier Detection

# %%
# histogram of Ozone
data_cleaned3['Ozone'].hist()
# Out:
# <Axes: >

# %%
#Box plot
plt.grid()
box = plt.boxplot(data_cleaned3["Ozone"],vert=False)

# %%
# #Extracting outliers
# box=plt.boxplot(data['Ozone'].dropna())

# %%
type(box)
# Out:
# dict

# %%
for i,j in box.items():
    print(i,j)
# Out:
# whiskers [<matplotlib.lines.Line2D object at 0x0000010C4FCFF0D0>, <matplotlib.lines.Line2D object at 0x0000010C505F6E10>]
# caps [<matplotlib.lines.Line2D object at 0x0000010C505F7990>, <matplotlib.lines.Line2D object at 0x0000010C50600550>]
# boxes [<matplotlib.lines.Line2D object at 0x0000010C4FF030D0>]
# medians [<matplotlib.lines.Line2D object at 0x0000010C50600F50>]
# fliers [<matplotlib.lines.Line2D object at 0x0000010C4FED19D0>]
# means []

# %%
[item.get_xdata() for item in box['fliers']] #fliers are outliers
# Out:
# [array([115., 135.,  97.,  97.,  85., 108.,  82., 122.,  89., 110., 168.,
#         118.,  84.,  85.,  96.,  91.])]

# %%
#To get the whiskers
[item.get_xdata()[1] for item in box['whiskers']]
# Out:
# [1.0, 80.0]

# %%
#Descriptive stat
data_cleaned3['Ozone'].describe()
# Out:
# count    157.000000
# mean      41.815126
# std       28.404353
# min        1.000000
# 25%       21.000000
# 50%       41.815126
# 75%       45.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
data_cleaned3
# Out:
#          Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0    41.000000  190.0   7.4    5.0    1  2010    67       S
# 1    36.000000  118.0   8.0    5.0    2  2010    72       C
# 2    12.000000  149.0  12.6    5.0    3  2010    74      PS
# 3    18.000000  313.0  11.5    5.0    4  2010    62       S
# 4    41.815126  199.0  14.3    5.0    5  2010    56       S
# ..         ...    ...   ...    ...  ...   ...   ...     ...
# 152  20.000000  223.0  11.5    9.0   30  2010    68       S
# 153  41.000000  190.0   7.4    5.0    1  2010    67       C
# 154  30.000000  193.0   6.9    9.0   26  2010    70      PS
# 155  41.815126  145.0  13.2    9.0   27  2010    77       S
# 157  18.000000  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %% [markdown]
# # Scatter plot and Correlation analysis

# %%
# Seaborn visualization library
import seaborn as sns
# Create the default pairplot
pd.plotting.scatter_matrix(data_cleaned3)
sns.pairplot(data_cleaned3)
# Out:
# C:\Users\shiva\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\misc.py:101: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# C:\Users\shiva\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\misc.py:102: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# C:\Users\shiva\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\misc.py:92: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(boundaries_list[i])

# %%
data_cleaned3.head(3)
# Out:
#    Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0   41.0  190.0   7.4    5.0    1  2010    67       S
# 1   36.0  118.0   8.0    5.0    2  2010    72       C
# 2   12.0  149.0  12.6    5.0    3  2010    74      PS

# %%
#Correlation
data_cleaned3.corr()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_10060\1879174665.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_cleaned3.corr()
#           Ozone     Solar      Wind     Month       Day  Year      Temp
# Ozone  1.000000  0.304572 -0.520004  0.132860 -0.021916   NaN  0.606500
# Solar  0.304572  1.000000 -0.057709 -0.094553 -0.156243   NaN  0.256994
# Wind  -0.520004 -0.057709  1.000000 -0.166216  0.029900   NaN -0.441228
# Month  0.132860 -0.094553 -0.166216  1.000000  0.050055   NaN  0.398516
# Day   -0.021916 -0.156243  0.029900  0.050055  1.000000   NaN -0.122787
# Year        NaN       NaN       NaN       NaN       NaN   NaN       NaN
# Temp   0.606500  0.256994 -0.441228  0.398516 -0.122787   NaN  1.000000

# %% [markdown]
# # Transformations

# %% [markdown]
# #### Dummy Variable

# %%
data_cleaned3
# Out:
#          Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0    41.000000  190.0   7.4    5.0    1  2010    67       S
# 1    36.000000  118.0   8.0    5.0    2  2010    72       C
# 2    12.000000  149.0  12.6    5.0    3  2010    74      PS
# 3    18.000000  313.0  11.5    5.0    4  2010    62       S
# 4    41.815126  199.0  14.3    5.0    5  2010    56       S
# ..         ...    ...   ...    ...  ...   ...   ...     ...
# 152  20.000000  223.0  11.5    9.0   30  2010    68       S
# 153  41.000000  190.0   7.4    5.0    1  2010    67       C
# 154  30.000000  193.0   6.9    9.0   26  2010    70      PS
# 155  41.815126  145.0  13.2    9.0   27  2010    77       S
# 157  18.000000  131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
#Creating dummy variable for Weather column
data_cleaned4=pd.get_dummies(data_cleaned3,columns=['Weather'])

# %%
data_cleaned4
# Out:
#          Ozone  Solar  Wind  Month  Day  Year  Temp  Weather_C  Weather_PS  \
# 0    41.000000  190.0   7.4    5.0    1  2010    67          0           0
# 1    36.000000  118.0   8.0    5.0    2  2010    72          1           0
# 2    12.000000  149.0  12.6    5.0    3  2010    74          0           1
# 3    18.000000  313.0  11.5    5.0    4  2010    62          0           0
# 4    41.815126  199.0  14.3    5.0    5  2010    56          0           0
# ..         ...    ...   ...    ...  ...   ...   ...        ...         ...
# 152  20.000000  223.0  11.5    9.0   30  2010    68          0           0
# 153  41.000000  190.0   7.4    5.0    1  2010    67          1           0
# 154  30.000000  193.0   6.9    9.0   26  2010    70          0           1
# 155  41.815126  145.0  13.2    9.0   27  2010    77          0           0
# 157  18.000000  131.0   8.0    9.0   29  2010    76          1           0
#
#      Weather_S
# 0            1
# 1            0
# 2            0
# 3            1
# 4            1
# ..         ...
# 152          1
# 153          0
# 154          0
# 155          1
# 157          0
#
# [157 rows x 10 columns]

# %%
data_cleaned4=data_cleaned4.dropna()

# %% [markdown]
# #### Normalization of the data

# %%
#Normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
data_cleaned4.values
# Out:
# array([[ 41.        , 190.        ,   7.4       , ...,   0.        ,
#           0.        ,   1.        ],
#        [ 36.        , 118.        ,   8.        , ...,   1.        ,
#           0.        ,   0.        ],
#        [ 12.        , 149.        ,  12.6       , ...,   0.        ,
#           1.        ,   0.        ],
#        ...,
#        [ 30.        , 193.        ,   6.9       , ...,   0.        ,
#           1.        ,   0.        ],
#        [ 41.81512605, 145.        ,  13.2       , ...,   0.        ,
#           0.        ,   1.        ],
#        [ 18.        , 131.        ,   8.        , ...,   1.        ,
#           0.        ,   0.        ]])

# %%
array = data_cleaned4.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array)

#transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[0.24 0.56 0.3  0.   0.   0.   0.27 0.   0.   1.  ]
#  [0.21 0.34 0.33 0.   0.03 0.   0.39 1.   0.   0.  ]
#  [0.07 0.43 0.57 0.   0.07 0.   0.44 0.   1.   0.  ]
#  [0.1  0.94 0.52 0.   0.1  0.   0.15 0.   0.   1.  ]
#  [0.24 0.59 0.66 0.   0.13 0.   0.   0.   0.   1.  ]]

# %%
# Standardize data (0 mean, 1 stdev)
from sklearn.preprocessing import StandardScaler

# %%
array = data_cleaned4.values
scaler = StandardScaler()
scaler.fit(array)
rescaledX = scaler.transform(array)

# summarize transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[-3.09e-02  3.95e-02 -7.19e-01 -1.43e+00 -1.66e+00  0.00e+00 -1.17e+00
#   -6.67e-01 -6.57e-01  1.25e+00]
#  [-2.07e-01 -7.91e-01 -5.47e-01 -1.43e+00 -1.55e+00  0.00e+00 -6.29e-01
#    1.50e+00 -6.57e-01 -8.01e-01]
#  [-1.05e+00 -4.33e-01  7.66e-01 -1.43e+00 -1.44e+00  0.00e+00 -4.14e-01
#   -6.67e-01  1.52e+00 -8.01e-01]
#  [-8.41e-01  1.46e+00  4.52e-01 -1.43e+00 -1.33e+00  0.00e+00 -1.70e+00
#   -6.67e-01 -6.57e-01  1.25e+00]
#  [-2.22e-03  1.43e-01  1.25e+00 -1.43e+00 -1.22e+00  0.00e+00 -2.35e+00
#   -6.67e-01 -6.57e-01  1.25e+00]]
